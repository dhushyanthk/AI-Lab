# %% [markdown]
# <a href="https://colab.research.google.com/github/dhushyanthk/AI-Lab/blob/main/EXP3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X_transpose = [[12,7],
    [4 ,5],
    [3 ,6]]

# Or, reuse X from the previous example:
matrix = X

result_transpose = [[0,0,0],
           [0,0,0],
           [0,0,0]]

# iterate through rows
for i in range(len(matrix)):
   # iterate through columns
   for j in range(len(matrix[0])):
       result_transpose[j][i] = matrix[i][j]

for r in result_transpose:
   print(r)
# Out:
# [12, 4, 7]
# [7, 5, 8]
# [3, 6, 9]
