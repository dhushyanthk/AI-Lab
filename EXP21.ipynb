# %% [markdown]
# <a href="https://colab.research.google.com/github/dhushyanthk/AI-Lab/blob/main/EXP21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print_board(board):
    """Prints the Tic Tac Toe board."""
    for row in board:
        print(" | ".join(row))
        print("---------")

def check_win(board, player):
    """Checks if the given player has won."""
    # Check rows
    for row in board:
        if all([s == player for s in row]):
            return True
    # Check columns
    for col in range(3):
        if all([board[row][col] == player for row in range(3)]):
            return True
    # Check diagonals
    if all([board[i][i] == player for i in range(3)]) or \
       all([board[i][2 - i] == player for i in range(3)]):
        return True
    return False

def check_draw(board):
    """Checks if the game is a draw."""
    for row in board:
        for spot in row:
            if spot == ' ':
                return False
    return True

def play_game():
    """Plays a game of Tic Tac Toe."""
    board = [[' ' for _ in range(3)] for _ in range(3)]
    current_player = 'X'
    game_over = False

    print("Welcome to Tic Tac Toe!")
    print_board(board)

    while not game_over:
        try:
            print(f"Player {current_player}, enter your move (row and column, e.g., 1 2 for row 1, col 2): ")
            move = input().split()
            row, col = int(move[0]) - 1, int(move[1]) - 1

            if 0 <= row < 3 and 0 <= col < 3 and board[row][col] == ' ':
                board[row][col] = current_player
                print_board(board)

                if check_win(board, current_player):
                    print(f"Player {current_player} wins!")
                    game_over = True
                elif check_draw(board):
                    print("It's a draw!")
                    game_over = True
                else:
                    current_player = 'O' if current_player == 'X' else 'X'
            else:
                print("Invalid move. Try again.")
        except (ValueError, IndexError):
            print("Invalid input. Please enter row and column as two numbers (e.g., 1 2).")

    print("Game over.")

# To play the game, uncomment the line below and run the cell:
play_game()
# Out:
# Welcome to Tic Tac Toe!
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player X, enter your move (row and column, e.g., 1 2 for row 1, col 2):
# 2 2
#   |   |
# ---------
#   | X |
# ---------
#   |   |
# ---------
# Player O, enter your move (row and column, e.g., 1 2 for row 1, col 2):
# 1 2
#   | O |
# ---------
#   | X |
# ---------
#   |   |
# ---------
# Player X, enter your move (row and column, e.g., 1 2 for row 1, col 2):
#  1 1
# X | O |
# ---------
#   | X |
# ---------
#   |   |
# ---------
# Player O, enter your move (row and column, e.g., 1 2 for row 1, col 2):
# 2 3
# X | O |
# ---------
#   | X | O
# ---------
#   |   |
# ---------
# Player X, enter your move (row and column, e.g., 1 2 for row 1, col 2):
# 3 3
# X | O |
# ---------
#   | X | O
# ---------
#   |   | X
# ---------
# Player X wins!
# Game over.

# %% [markdown]
# To play the game, uncomment the last line `# play_game()` in the code cell above and run it. You will be prompted to enter your moves in the input box.
