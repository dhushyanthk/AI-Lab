# %% [markdown]
# <a href="https://colab.research.google.com/github/dhushyanthk/AI-Lab/blob/main/EXP20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Map Coloring as a Constraint Satisfaction Problem (CSP)
#
# Map coloring is a classic problem in computer science and artificial intelligence. The goal is to assign colors to regions on a map such that no two adjacent regions have the same color, using the minimum number of colors. This problem can be modeled as a Constraint Satisfaction Problem (CSP).
#
# **Components of a CSP:**
# *   **Variables:** Each region on the map is a variable.
# *   **Domains:** The set of possible colors that can be assigned to each region.
# *   **Constraints:** For every pair of adjacent regions, the constraint is that they must have different colors.

# %%
class CSP:
    def __init__(self, variables, domains, neighbors, constraints):
        self.variables = variables
        self.domains = domains
        self.neighbors = neighbors
        self.constraints = constraints

    def backtracking_search(self):
        return self.backtrack({})

    def backtrack(self, assignment):
        # If all variables are assigned, then we have a solution
        if len(assignment) == len(self.variables):
            return assignment

        # Select an unassigned variable
        unassigned = [v for v in self.variables if v not in assignment]
        var = min(unassigned, key=lambda v: len(self.domains[v])) # Minimum Remaining Values heuristic

        # Try each value in the variable's domain
        for value in self.domains[var]:
            if self.is_consistent(var, value, assignment):
                assignment[var] = value
                result = self.backtrack(assignment)
                if result is not None:
                    return result
                del assignment[var] # Backtrack
        return None

    def is_consistent(self, var, value, assignment):
        # Check if assigning 'value' to 'var' is consistent with current assignment
        for neighbor in self.neighbors[var]:
            if neighbor in assignment and assignment[neighbor] == value:
                return False
        return True

# Define the map coloring problem for Australia
variables = ['WA', 'NT', 'SA', 'Q', 'NSW', 'V', 'T']

domains = {
    'WA': ['red', 'green', 'blue'],
    'NT': ['red', 'green', 'blue'],
    'SA': ['red', 'green', 'blue'],
    'Q': ['red', 'green', 'blue'],
    'NSW': ['red', 'green', 'blue'],
    'V': ['red', 'green', 'blue'],
    'T': ['red', 'green', 'blue']
}

neighbors = {
    'WA': ['NT', 'SA'],
    'NT': ['WA', 'SA', 'Q'],
    'SA': ['WA', 'NT', 'Q', 'NSW', 'V'],
    'Q': ['NT', 'SA', 'NSW'],
    'NSW': ['Q', 'SA', 'V'],
    'V': ['SA', 'NSW'],
    'T': []
}

# Constraints are implicitly handled by the is_consistent function: adjacent regions must have different colors
# For simplicity, we don't need an explicit 'constraints' list here as the check is embedded.
constraints = [] # Placeholder, as constraints are checked dynamically

# Create a CSP instance
map_coloring_csp = CSP(variables, domains, neighbors, constraints)

# Solve the CSP
solution = map_coloring_csp.backtracking_search()

# Display the solution
if solution:
    print("Map Coloring Solution (Australia):")
    for region, color in solution.items():
        print(f"{region}: {color}")
else:
    print("No solution found.")
# Out:
# Map Coloring Solution (Australia):
# WA: red
# NT: green
# SA: blue
# Q: red
# NSW: green
# V: red
# T: red
