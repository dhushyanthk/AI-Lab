# %% [markdown]
# <a href="https://colab.research.google.com/github/dhushyanthk/AI-Lab/blob/main/EXP07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

print(f"Set 1: {set1}")
print(f"Set 2: {set2}")

# Union of two sets
union_set = set1.union(set2)
print(f"Union of Set 1 and Set 2: {union_set}")

# Intersection of two sets
intersection_set = set1.intersection(set2)
print(f"Intersection of Set 1 and Set 2: {intersection_set}")

# Difference of two sets (elements in set1 but not in set2)
difference_set1_2 = set1.difference(set2)
print(f"Difference (Set1 - Set2): {difference_set1_2}")

# Difference of two sets (elements in set2 but not in set1)
difference_set2_1 = set2.difference(set1)
print(f"Difference (Set2 - Set1): {difference_set2_1}")

# Symmetric Difference of two sets (elements in either set1 or set2 but not in both)
symmetric_difference_set = set1.symmetric_difference(set2)
print(f"Symmetric Difference: {symmetric_difference_set}")
# Out:
# Set 1: {1, 2, 3, 4, 5}
# Set 2: {4, 5, 6, 7, 8}
# Union of Set 1 and Set 2: {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection of Set 1 and Set 2: {4, 5}
# Difference (Set1 - Set2): {1, 2, 3}
# Difference (Set2 - Set1): {8, 6, 7}
# Symmetric Difference: {1, 2, 3, 6, 7, 8}
