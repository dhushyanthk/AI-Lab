# %% [markdown]
# <a href="https://colab.research.google.com/github/dhushyanthk/AI-Lab/blob/main/EXP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence = input("Enter a sentence: ")

# Split the sentence into words
words = sentence.split()

# Sort the words alphabetically (case-insensitive)
sorted_words = sorted(words, key=str.lower)

# Join the sorted words back into a sentence
sorted_sentence = ' '.join(sorted_words)

print("Original sentence:", sentence)
print("Sorted sentence (alphabetical order):", sorted_sentence)
# Out:
# Enter a sentence: HELLO WORLD PYTHON
# Original sentence: HELLO WORLD PYTHON
# Sorted sentence (alphabetical order): HELLO PYTHON WORLD
