# %% [markdown]
# <a href="https://colab.research.google.com/github/dhushyanthk/AI-Lab/blob/main/EXP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculator():
    print("Simple Calculator Program")
    print("----------------------")

    try:
        num1 = float(input("Enter first number: "))
        operator = input("Enter operator (+, -, *, /): ")
        num2 = float(input("Enter second number: "))

        if operator == '+':
            result = num1 + num2
        elif operator == '-':
            result = num1 - num2
        elif operator == '*':
            result = num1 * num2
        elif operator == '/':
            if num2 == 0:
                print("Error: Division by zero is not allowed.")
                return
            result = num1 / num2
        else:
            print("Error: Invalid operator. Please use +, -, *, or /.")
            return

        print(f"The result is: {result}")

    except ValueError:
        print("Error: Invalid input. Please enter numbers for calculations.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

calculator()
# Out:
# Simple Calculator Program
# ----------------------
# Enter first number: 5
# Enter operator (+, -, *, /): +
# Enter second number: 7
# The result is: 12.0
